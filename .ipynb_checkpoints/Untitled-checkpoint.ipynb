# %%
import pandas as pd

df=pd.read_csv('Data/AviationData.csv', encoding='latin-1')
df
# Out:
# C:\Users\johns\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
df.isnull().sum()
df['Location'].value_counts()
# Out:
# ANCHORAGE, AK             434
# MIAMI, FL                 200
# ALBUQUERQUE, NM           196
# HOUSTON, TX               193
# CHICAGO, IL               184
#                          ...
# DAVENPORT, NE               1
# Onalaska, TX                1
# Birr, Ireland, Ireland      1
# Lincolnton, GA              1
# BERGAMO, ITALY              1
# Name: Location, Length: 27758, dtype: int64

# %%
column_names = list(df.columns)


for x in column_names:
    print(df[x].value_counts())
# Out:
# 20001214X45071    3
# 20001212X19172    3
# 20001211X14328    2
# 20001208X09058    2
# 20051206X01938    2
#                  ..
# 20200423X91852    1
# 20081003X17530    1
# 20001213X29117    1
# 20151005X12529    1
# 20001213X25826    1
# Name: Event.Id, Length: 87951, dtype: int64
# Accident    85015
# Incident     3874
# Name: Investigation.Type, dtype: int64
# ERA22FA318    2
# ERA22LA119    2
# CEN22LA149    2
# DCA23WA071    2
# ERA22LA364    2
#              ..
# ERA10LA349    1
# CHI85LA203    1
# CEN21LA363    1
# CEN11CA624    1
# ANC14FA062    1
# Name: Accident.Number, Length: 88863, dtype: int64
# 1982-05-16    25
# 1984-06-30    25
# 2000-07-08    25
# 1986-05-17    24
# 1983-06-05    24
#               ..
# 2012-12-16     1
# 2019-02-19     1
# 2016-02-19     1
# 2014-08-04     1
# 2017-01-13     1
# Name: Event.Date, Length: 14782, dtype: int64
# ANCHORAGE, AK             434
# MIAMI, FL                 200
# ALBUQUERQUE, NM           196
# ...

# %%
df.loc[df['Event.Id'] == '20001214X45071']
# Out:
#             Event.Id Investigation.Type Accident.Number  Event.Date  \
# 6781  20001214X45071           Accident     FTW84LA056C  1983-11-11
# 6784  20001214X45071           Accident     FTW84LA056B  1983-11-11
# 6785  20001214X45071           Accident     FTW84LA056A  1983-11-11
#
#          Location        Country Latitude Longitude Airport.Code Airport.Name  \
# 6781  HOUSTON, TX  United States      NaN       NaN          AAP       ANDRAU
# 6784  HOUSTON, TX  United States      NaN       NaN          AAP       ANDRAU
# 6785  HOUSTON, TX  United States      NaN       NaN          AAP       ANDRAU
#
#       ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 6781  ...          Business         NaN                  0.0
# 6784  ...          Personal         NaN                  0.0
# 6785  ...          Personal         NaN                  0.0
#
#      Total.Serious.Injuries Total.Minor.Injuries Total.Uninjured  \
# ...

# %%
subset = df.loc[(df['Injury.Severity'] == 'Fatal(1)') | (df['Injury.Severity'] == 'Fatal') | (df['Injury.Severity'] == 'Fatal(2)')]
# subset.sort_values(by = 'Total.Fatal.Injuries', ascending =False)
subset.sort_values(by = 'Event.Date', ascending =True)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# 13     20020917X02134           Accident      FTW82FRA14  1982-01-02
# 14     20020917X02119           Accident      FTW82FPJ10  1982-01-02
# ...               ...                ...             ...         ...
# 88843  20221205106408           Accident      CEN23FA057  2022-12-04
# 88845  20221205106417           Accident      CEN23FA059  2022-12-05
# 88846  20221206106419           Accident      CEN23FA060  2022-12-05
# 88868  20221213106451           Accident      ERA23FA087  2022-12-13
# 88883  20221228106502           Accident      GAA23WA046  2022-12-22
#
#               Location        Country Latitude Longitude Airport.Code  \
# ...

# %%
subset.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     14
# Country                      39
# Latitude                   8544
# Longitude                  8544
# Airport.Code               9030
# Airport.Name               8790
# Injury.Severity               0
# Aircraft.damage             213
# Aircraft.Category          9252
# Registration.Number         304
# Make                         15
# Model                        21
# Amateur.Built                17
# Number.of.Engines          1654
# Engine.Type                2033
# FAR.Description            9395
# Schedule                  13676
# Purpose.of.flight          1343
# Air.carrier               12287
# Total.Fatal.Injuries          0
# Total.Serious.Injuries     2035
# Total.Minor.Injuries       2262
# Total.Uninjured            2284
# Weather.Condition          1427
# Broad.phase.of.flight      5732
# ...
